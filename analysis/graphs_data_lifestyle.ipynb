# %%
#import dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import scipy.stats as st
import scipy.stats as stats

# %%
#Read in dataset
df = pd.read_csv('../datasets/Sleep_health_and_lifestyle_dataset.csv')
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# Create a scatter plot of the data

plt.scatter(df['Age'], df['Sleep Duration'], label='Data Points')

# Calculate the linear regression line using linregress
slope, intercept, r_value, p_value, std_err = linregress(df['Age'], df['Sleep Duration'])

# Plot the linear regression line
plt.plot(df['Age'], slope * df['Age'] + intercept, color='red', label='Linear Regression Line')

# Add the linear regression equation as a text annotation on the plot
equation = f'y = {slope:.2f}x + {intercept:.2f}'
plt.text(0.5, 0.9, equation, ha='center', va='center', transform=plt.gca().transAxes, color='red')

plt.xlabel('Age')
plt.ylabel('Sleep Duration')
plt.title('Linear Regression of Age vs Sleep Duration')
plt.savefig("figures/age_sleep.png")

plt.show()
correlation = st.pearsonr(df['Age'], df['Sleep Duration'])
print(f"The Pearson correlation coefficient between both factors is {round(correlation[0],2)}")
print(f"The r-squared is: {r_value**2}")
print("The p-value is:", p_value)


#Used Xpert Learning Assistance
# Out:
# The Pearson correlation coefficient between both factors is 0.34
# The r-squared is: 0.11882454160634962
# The p-value is: 7.1171395312160525e-12

# %%
# The degree of freedom is 3-1 = 2
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95.
critical_value = stats.chi2.ppf(q = 0.95, df = 373)
# The critical value
critical_value

# Run the chi square test with stats.chisquare()
#stats.chisquare(df['Age'], df['Sleep Duration'])
# Out:
# 419.0338616916437

# %%
clean_df = df[["Gender","Sleep Duration"]]
clean_df
# Out:
#      Gender  Sleep Duration
# 0      Male             6.1
# 1      Male             6.2
# 2      Male             6.2
# 3      Male             5.9
# 4      Male             5.9
# ..      ...             ...
# 369  Female             8.1
# 370  Female             8.0
# 371  Female             8.1
# 372  Female             8.1
# 373  Female             8.1
#
# [374 rows x 2 columns]

# %%
gender_and_sleep = clean_df[["Gender","Sleep Duration"]]
plt.bar(gender_and_sleep['Gender'], gender_and_sleep['Sleep Duration'])

plt.title("Gender vs Sleep Distribution")
plt.xlabel("Gender")
plt.ylabel("Sleep Duration")
plt.savefig("figures/gender_sleep.png")
plt.show()

# %%
new_df = df[["BMI Category","Sleep Duration"]]
new_df
# Out:
#     BMI Category  Sleep Duration
# 0     Overweight             6.1
# 1         Normal             6.2
# 2         Normal             6.2
# 3          Obese             5.9
# 4          Obese             5.9
# ..           ...             ...
# 369   Overweight             8.1
# 370   Overweight             8.0
# 371   Overweight             8.1
# 372   Overweight             8.1
# 373   Overweight             8.1
#
# [374 rows x 2 columns]

# %%
bmi_and_sleep = new_df[["BMI Category","Sleep Duration"]]
plt.bar(bmi_and_sleep['BMI Category'], gender_and_sleep['Sleep Duration'])

plt.title("BMI vs Sleep Distribution")
plt.xlabel("BMI")
plt.ylabel("Sleep Duration")
plt.show()
